# %%
step = 4  # take every 4th pixel in each dimension
# first :

rgb_small = mb[::step, ::step, :3]
mask_small = mask[::step, ::step]
pred_small = pred_ndsi[::step, ::step]

fig, ax = plt.subplots(1, 3, figsize=(12, 4))

ax[0].imshow(rgb_small)
ax[0].set_title("RGB (downsampled)")
ax[0].axis("off")

ax[1].imshow(mask_small, cmap="gray")
ax[1].set_title("Mask (downsampled)")
ax[1].axis("off")

ax[2].imshow(pred_small, cmap="gray")
ax[2].set_title("NDSI prediction (downsampled)")
ax[2].axis("off")

plt.show()
